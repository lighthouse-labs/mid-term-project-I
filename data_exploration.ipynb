# %%
import pandas as pd
pd.set_option("display.max_columns", 100)
pd.set_option("display.max_rows", 100)

# %%
df = pd.read_csv("/Users/jurajkapasny/Downloads/1050026712_T_ONTIME_JAN_2020.csv")

# %%
df.shape
# Out:
# (660556, 41)

# %%
df.head(20)
# Out:
#        FL_DATE MKT_UNIQUE_CARRIER BRANDED_CODE_SHARE MKT_CARRIER  \
# 0   01/01/2020                 WN                 WN          WN
# 1   01/01/2020                 WN                 WN          WN
# 2   01/01/2020                 WN                 WN          WN
# 3   01/01/2020                 WN                 WN          WN
# 4   01/01/2020                 WN                 WN          WN
# 5   01/01/2020                 WN                 WN          WN
# 6   01/01/2020                 WN                 WN          WN
# 7   01/01/2020                 WN                 WN          WN
# 8   01/01/2020                 WN                 WN          WN
# 9   01/01/2020                 WN                 WN          WN
# 10  01/01/2020                 WN                 WN          WN
# 11  01/01/2020                 WN                 WN          WN
# 12  01/01/2020                 WN                 WN          WN
# ...

# %%
df.ORIGIN.value_counts()[df.ORIGIN.value_counts().index == "JFK"]
# Out:
# JFK    10312
# Name: ORIGIN, dtype: int64

# %%
df.ORIGIN.value_counts()
# Out:
# ATL    32201
# ORD    31365
# DFW    24339
# DEN    22840
# CLT    21988
#        ...
# UIN       10
# ADK        9
# OGD        9
# PPG        9
# OWB        9
# Name: ORIGIN, Length: 365, dtype: int64

# %%
df[df.CARRIER_DELAY.notnull()]
# Out:
#            FL_DATE MKT_UNIQUE_CARRIER BRANDED_CODE_SHARE MKT_CARRIER  \
# 0       01/01/2020                 WN                 WN          WN
# 7       01/01/2020                 WN                 WN          WN
# 14      01/01/2020                 WN                 WN          WN
# 24      01/01/2020                 WN                 WN          WN
# 29      01/01/2020                 WN                 WN          WN
# ...            ...                ...                ...         ...
# 660468  31/01/2020                 DL       DL_CODESHARE          DL
# 660482  31/01/2020                 DL       DL_CODESHARE          DL
# 660485  31/01/2020                 DL       DL_CODESHARE          DL
# 660502  31/01/2020                 DL       DL_CODESHARE          DL
# 660554  31/01/2020                 DL       DL_CODESHARE          DL
#
#         MKT_CARRIER_FL_NUM OP_UNIQUE_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  \
# ...

# %%
df.CANCELLED.value_counts()
# Out:
# 0    652140
# 1      8416
# Name: CANCELLED, dtype: int64

# %%
df[df.CANCELLED == 1]
# Out:
#            FL_DATE MKT_UNIQUE_CARRIER BRANDED_CODE_SHARE MKT_CARRIER  \
# 35      01/01/2020                 WN                 WN          WN
# 839     01/01/2020                 WN                 WN          WN
# 1734    01/01/2020                 HA       HA_CODESHARE          HA
# 1735    01/01/2020                 HA       HA_CODESHARE          HA
# 1736    01/01/2020                 HA       HA_CODESHARE          HA
# ...            ...                ...                ...         ...
# 659747  31/01/2020                 UA       UA_CODESHARE          UA
# 659749  31/01/2020                 UA       UA_CODESHARE          UA
# 659767  31/01/2020                 UA       UA_CODESHARE          UA
# 659793  31/01/2020                 UA       UA_CODESHARE          UA
# 659838  31/01/2020                 UA       UA_CODESHARE          UA
#
#         MKT_CARRIER_FL_NUM OP_UNIQUE_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  \
# ...

# %%
tt = pd.read_csv("/Users/jurajkapasny/Downloads/28673295_T_F41SCHEDULE_P12A.csv")

# %%
df.OP_UNIQUE_CARRIER.value_counts()
# Out:
# WN    109770
# DL     80067
# AA     76276
# OO     71133
# UA     48401
# YX     29121
# MQ     26201
# B6     24709
# OH     24311
# 9E     23088
# AS     21110
# YV     17836
# NK     17477
# F9     12467
# PT     10657
# EV     10591
# QX     10296
# ZW      8884
# G4      7774
# HA      7035
# AX      6424
# G7      5811
# CP      5741
# C5      4624
# EM       752
# Name: OP_UNIQUE_CARRIER, dtype: int64

# %%
tt[tt.UNIQUE_CARRIER == 'DL']
# Out:
#      MONTH  AIRLINE_ID UNIQUE_CARRIER CARRIER          CARRIER_NAME  \
# 17       1       19790             DL      DL  Delta Air Lines Inc.
# 68       2       19790             DL      DL  Delta Air Lines Inc.
# 118      3       19790             DL      DL  Delta Air Lines Inc.
# 169      4       19790             DL      DL  Delta Air Lines Inc.
# 220      5       19790             DL      DL  Delta Air Lines Inc.
# 271      6       19790             DL      DL  Delta Air Lines Inc.
# 322      7       19790             DL      DL  Delta Air Lines Inc.
# 373      8       19790             DL      DL  Delta Air Lines Inc.
# 424      9       19790             DL      DL  Delta Air Lines Inc.
#
#      CARRIER_GROUP_NEW  SDOMT_GALLONS  SATL_GALLONS  SPAC_GALLONS  \
# 17                   3    165835898.0    48129821.0    28376721.0
# 68                   3    152322966.0    42273867.0    24710323.0
# 118                  3    187116451.0    51208157.0    29039222.0
# ...
